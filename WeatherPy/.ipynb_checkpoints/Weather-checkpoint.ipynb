# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
record = 0
set_num = 1
weather_list = {}
lat = []
long = []
temp = []
humid = []
cloud = []
wind = []
name = []
country = []
date = []

url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + api_key + "&units=" + "imperial" + "&q="
print('Beginning Data Gathering')
print("-----------------")
for city in cities:
    try:
        record += 1
        query = f"{url}{city}&format=json"
        response = requests.get(query).json()
        weather_list[city] = response
        print(f'Processing Record {record} in Set {set_num} | {city}')
        lat.append(weather_list[f'{city}']['coord']['lat'])
        long.append(weather_list[f'{city}']['coord']['lon'])
        temp.append(weather_list[f'{city}']['main']['temp_max'])
        humid.append(weather_list[f'{city}']['main']['humidity'])
        cloud.append(weather_list[f'{city}']['clouds']['all'])
        wind.append(weather_list[f'{city}']['wind']['speed'])
        name.append(weather_list[f'{city}']['name'])
        country.append(weather_list[f'{city}']['sys']['country'])
        date.append(weather_list[f'{city}']['dt'])
    except KeyError:
        print("City not found, skipping")
        record = record - 1
    if record==50:
        record = 0
        set_num += 1
        time.sleep(5)
print("-----------------")
print("Data Gathering Complete")
# Out:
# Beginning Data Gathering
# -----------------
# Processing Record 1 in Set 1 | sitka
# Processing Record 2 in Set 1 | punta arenas
# Processing Record 3 in Set 1 | lagoa
# Processing Record 4 in Set 1 | taolanaro
# City not found, skipping
# Processing Record 4 in Set 1 | nadym
# Processing Record 5 in Set 1 | atuona
# Processing Record 6 in Set 1 | lindi
# Processing Record 7 in Set 1 | nikolskoye
# Processing Record 8 in Set 1 | bambous virieux
# Processing Record 9 in Set 1 | pangai
# Processing Record 10 in Set 1 | albany
# Processing Record 11 in Set 1 | constitucion
# Processing Record 12 in Set 1 | lebu
# Processing Record 13 in Set 1 | upernavik
# Processing Record 14 in Set 1 | vaini
# Processing Record 15 in Set 1 | ushuaia
# Processing Record 16 in Set 1 | traverse city
# Processing Record 17 in Set 1 | bereda
# Processing Record 18 in Set 1 | hermanus
# Processing Record 19 in Set 1 | honiara
# Processing Record 20 in Set 1 | thompson
# Processing Record 21 in Set 1 | saldanha
# Processing Record 22 in Set 1 | saint-philippe
# Processing Record 23 in Set 1 | port elizabeth
# Processing Record 24 in Set 1 | arraial do cabo
# Processing Record 25 in Set 1 | tsihombe
# City not found, skipping
# Processing Record 25 in Set 1 | mahebourg
# Processing Record 26 in Set 1 | ulaangom
# Processing Record 27 in Set 1 | sur
# Processing Record 28 in Set 1 | guerrero negro
# Processing Record 29 in Set 1 | tabas
# Processing Record 30 in Set 1 | ko samui
# Processing Record 31 in Set 1 | mar del plata
# Processing Record 32 in Set 1 | souillac
# Processing Record 33 in Set 1 | saint george
# Processing Record 34 in Set 1 | puerto ayora
# Processing Record 35 in Set 1 | kuri
# Processing Record 36 in Set 1 | busselton
# Processing Record 37 in Set 1 | ilulissat
# Processing Record 38 in Set 1 | buala
# Processing Record 39 in Set 1 | cabo san lucas
# Processing Record 40 in Set 1 | makakilo city
# Processing Record 41 in Set 1 | tasiilaq
# Processing Record 42 in Set 1 | channel-port aux basques
# Processing Record 43 in Set 1 | kodiak
# Processing Record 44 in Set 1 | najran
# Processing Record 45 in Set 1 | ribeira grande
# Processing Record 46 in Set 1 | chiali
# City not found, skipping
# Processing Record 46 in Set 1 | havre-saint-pierre
# Processing Record 47 in Set 1 | hobart
# Processing Record 48 in Set 1 | kruisfontein
# Processing Record 49 in Set 1 | aguada de pasajeros
# Processing Record 50 in Set 1 | gerash
# Processing Record 1 in Set 2 | kapaa
# Processing Record 2 in Set 2 | palabuhanratu
# City not found, skipping
# Processing Record 2 in Set 2 | itarema
# Processing Record 3 in Set 2 | isangel
# Processing Record 4 in Set 2 | tiksi
# Processing Record 5 in Set 2 | attawapiskat
# City not found, skipping
# Processing Record 5 in Set 2 | port lincoln
# Processing Record 6 in Set 2 | rikitea
# Processing Record 7 in Set 2 | manutuke
# Processing Record 8 in Set 2 | butaritari
# Processing Record 9 in Set 2 | mataura
# Processing Record 10 in Set 2 | katsuura
# Processing Record 11 in Set 2 | tommot
# Processing Record 12 in Set 2 | salalah
# Processing Record 13 in Set 2 | barentsburg
# City not found, skipping
# Processing Record 13 in Set 2 | castro
# Processing Record 14 in Set 2 | bethel
# Processing Record 15 in Set 2 | bredasdorp
# Processing Record 16 in Set 2 | yarada
# Processing Record 17 in Set 2 | gryazovets
# Processing Record 18 in Set 2 | ambovombe
# Processing Record 19 in Set 2 | hervey bay
# Processing Record 20 in Set 2 | victoria
# Processing Record 21 in Set 2 | abay
# Processing Record 22 in Set 2 | yellowknife
# Processing Record 23 in Set 2 | abapo
# Processing Record 24 in Set 2 | coahuayana
# Processing Record 25 in Set 2 | bengkulu
# City not found, skipping
# Processing Record 25 in Set 2 | hofn
# Processing Record 26 in Set 2 | hasaki
# Processing Record 27 in Set 2 | ketchikan
# Processing Record 28 in Set 2 | necochea
# Processing Record 29 in Set 2 | yenagoa
# Processing Record 30 in Set 2 | pevek
# Processing Record 31 in Set 2 | bluff
# Processing Record 32 in Set 2 | kendal
# Processing Record 33 in Set 2 | slave lake
# Processing Record 34 in Set 2 | sinnamary
# Processing Record 35 in Set 2 | monrovia
# Processing Record 36 in Set 2 | bandarbeyla
# Processing Record 37 in Set 2 | luderitz
# Processing Record 38 in Set 2 | barrow
# Processing Record 39 in Set 2 | poum
# Processing Record 40 in Set 2 | coihaique
# Processing Record 41 in Set 2 | miramar
# Processing Record 42 in Set 2 | blythe
# Processing Record 43 in Set 2 | bad kreuznach
# Processing Record 44 in Set 2 | clarence town
# Processing Record 45 in Set 2 | yecla
# Processing Record 46 in Set 2 | saskylakh
# Processing Record 47 in Set 2 | abu samrah
# Processing Record 48 in Set 2 | cape town
# Processing Record 49 in Set 2 | emba
# Processing Record 50 in Set 2 | chokurdakh
# Processing Record 1 in Set 3 | esperance
# Processing Record 2 in Set 3 | sabang
# Processing Record 3 in Set 3 | cherskiy
# Processing Record 4 in Set 3 | baft
# Processing Record 5 in Set 3 | avera
# Processing Record 6 in Set 3 | campbellton
# Processing Record 7 in Set 3 | gongzhuling
# Processing Record 8 in Set 3 | katherine
# Processing Record 9 in Set 3 | eldorado
# Processing Record 10 in Set 3 | georgetown
# Processing Record 11 in Set 3 | pacific grove
# Processing Record 12 in Set 3 | buta
# Processing Record 13 in Set 3 | padang
# Processing Record 14 in Set 3 | aykhal
# Processing Record 15 in Set 3 | pyinmana
# Processing Record 16 in Set 3 | ust-maya
# Processing Record 17 in Set 3 | naujoji akmene
# Processing Record 18 in Set 3 | sentyabrskiy
# City not found, skipping
# Processing Record 18 in Set 3 | yar-sale
# Processing Record 19 in Set 3 | altay
# Processing Record 20 in Set 3 | vaitupu
# City not found, skipping
# Processing Record 20 in Set 3 | dongsheng
# Processing Record 21 in Set 3 | adre
# Processing Record 22 in Set 3 | nara
# Processing Record 23 in Set 3 | trairi
# Processing Record 24 in Set 3 | hyeres
# Processing Record 25 in Set 3 | los llanos de aridane
# Processing Record 26 in Set 3 | huilong
# Processing Record 27 in Set 3 | atasu
# Processing Record 28 in Set 3 | diamantino
# Processing Record 29 in Set 3 | rancho palos verdes
# Processing Record 30 in Set 3 | camacupa
# Processing Record 31 in Set 3 | khatanga
# Processing Record 32 in Set 3 | severo-kurilsk
# Processing Record 33 in Set 3 | port alfred
# Processing Record 34 in Set 3 | provideniya
# Processing Record 35 in Set 3 | flinders
# Processing Record 36 in Set 3 | saint-francois
# Processing Record 37 in Set 3 | longyearbyen
# Processing Record 38 in Set 3 | ybycui
# Processing Record 39 in Set 3 | vyyezdnoye
# Processing Record 40 in Set 3 | sajanan
# Processing Record 41 in Set 3 | avarua
# Processing Record 42 in Set 3 | khandyga
# Processing Record 43 in Set 3 | tome-acu
# City not found, skipping
# Processing Record 43 in Set 3 | illoqqortoormiut
# City not found, skipping
# Processing Record 43 in Set 3 | kizukuri
# Processing Record 44 in Set 3 | katobu
# Processing Record 45 in Set 3 | fairbanks
# Processing Record 46 in Set 3 | klaksvik
# Processing Record 47 in Set 3 | carnarvon
# Processing Record 48 in Set 3 | charagua
# Processing Record 49 in Set 3 | ust-kamchatsk
# City not found, skipping
# Processing Record 49 in Set 3 | port macquarie
# Processing Record 50 in Set 3 | salta
# Processing Record 1 in Set 4 | pimenta bueno
# Processing Record 2 in Set 4 | marsh harbour
# Processing Record 3 in Set 4 | jamestown
# Processing Record 4 in Set 4 | husavik
# Processing Record 5 in Set 4 | qaanaaq
# Processing Record 6 in Set 4 | beloha
# Processing Record 7 in Set 4 | esfahan
# Processing Record 8 in Set 4 | champerico
# Processing Record 9 in Set 4 | grindavik
# Processing Record 10 in Set 4 | hambantota
# Processing Record 11 in Set 4 | hithadhoo
# Processing Record 12 in Set 4 | hilo
# Processing Record 13 in Set 4 | olafsvik
# City not found, skipping
# Processing Record 13 in Set 4 | praia da vitoria
# Processing Record 14 in Set 4 | roebourne
# Processing Record 15 in Set 4 | san patricio
# Processing Record 16 in Set 4 | alenquer
# Processing Record 17 in Set 4 | tual
# Processing Record 18 in Set 4 | campbell river
# Processing Record 19 in Set 4 | quatre cocos
# Processing Record 20 in Set 4 | meulaboh
# Processing Record 21 in Set 4 | pinheiro machado
# Processing Record 22 in Set 4 | samalaeulu
# City not found, skipping
# Processing Record 22 in Set 4 | tinskoy
# Processing Record 23 in Set 4 | sao filipe
# Processing Record 24 in Set 4 | kaitangata
# Processing Record 25 in Set 4 | broome
# Processing Record 26 in Set 4 | rawson
# Processing Record 27 in Set 4 | east london
# Processing Record 28 in Set 4 | tuatapere
# Processing Record 29 in Set 4 | praxedis guerrero
# Processing Record 30 in Set 4 | fort nelson
# Processing Record 31 in Set 4 | komsomolskiy
# Processing Record 32 in Set 4 | vila franca do campo
# Processing Record 33 in Set 4 | ordzhonikidze
# Processing Record 34 in Set 4 | chagda
# City not found, skipping
# Processing Record 34 in Set 4 | ponta do sol
# Processing Record 35 in Set 4 | lugoba
# Processing Record 36 in Set 4 | umzimvubu
# City not found, skipping
# Processing Record 36 in Set 4 | skjeberg
# Processing Record 37 in Set 4 | nago
# Processing Record 38 in Set 4 | batangafo
# Processing Record 39 in Set 4 | samarai
# Processing Record 40 in Set 4 | port shepstone
# Processing Record 41 in Set 4 | porangatu
# Processing Record 42 in Set 4 | mys shmidta
# City not found, skipping
# Processing Record 42 in Set 4 | polyarnyye zori
# Processing Record 43 in Set 4 | westport
# Processing Record 44 in Set 4 | shyryayeve
# Processing Record 45 in Set 4 | ponta delgada
# Processing Record 46 in Set 4 | mandapam
# Processing Record 47 in Set 4 | airai
# Processing Record 48 in Set 4 | pindi gheb
# Processing Record 49 in Set 4 | calvinia
# Processing Record 50 in Set 4 | pringsewu
# Processing Record 1 in Set 5 | san policarpo
# Processing Record 2 in Set 5 | new norfolk
# Processing Record 3 in Set 5 | dicabisagan
# Processing Record 4 in Set 5 | jalu
# Processing Record 5 in Set 5 | belushya guba
# City not found, skipping
# Processing Record 5 in Set 5 | sombreffe
# Processing Record 6 in Set 5 | talawdi
# City not found, skipping
# Processing Record 6 in Set 5 | norman wells
# Processing Record 7 in Set 5 | kahului
# Processing Record 8 in Set 5 | salair
# Processing Record 9 in Set 5 | hirara
# Processing Record 10 in Set 5 | obo
# Processing Record 11 in Set 5 | londiani
# Processing Record 12 in Set 5 | erenhot
# Processing Record 13 in Set 5 | zonguldak
# Processing Record 14 in Set 5 | belaya gora
# Processing Record 15 in Set 5 | ambodifototra
# City not found, skipping
# Processing Record 15 in Set 5 | lubao
# Processing Record 16 in Set 5 | akyab
# City not found, skipping
# Processing Record 16 in Set 5 | rio gallegos
# Processing Record 17 in Set 5 | shar
# Processing Record 18 in Set 5 | lucea
# Processing Record 19 in Set 5 | ahipara
# Processing Record 20 in Set 5 | illapel
# Processing Record 21 in Set 5 | kiunga
# Processing Record 22 in Set 5 | ust-kuyga
# Processing Record 23 in Set 5 | anadyr
# Processing Record 24 in Set 5 | kiruna
# Processing Record 25 in Set 5 | manaure
# Processing Record 26 in Set 5 | pangody
# Processing Record 27 in Set 5 | mehamn
# Processing Record 28 in Set 5 | contamana
# Processing Record 29 in Set 5 | takob
# City not found, skipping
# Processing Record 29 in Set 5 | urumqi
# City not found, skipping
# Processing Record 29 in Set 5 | horki
# Processing Record 30 in Set 5 | karasjok
# Processing Record 31 in Set 5 | louisbourg
# City not found, skipping
# Processing Record 31 in Set 5 | reshetnikovo
# Processing Record 32 in Set 5 | san cristobal
# Processing Record 33 in Set 5 | saleaula
# City not found, skipping
# Processing Record 33 in Set 5 | oromocto
# Processing Record 34 in Set 5 | saint anthony
# Processing Record 35 in Set 5 | urdzhar
# City not found, skipping
# Processing Record 35 in Set 5 | deputatskiy
# Processing Record 36 in Set 5 | mount pleasant
# Processing Record 37 in Set 5 | southbridge
# Processing Record 38 in Set 5 | caravelas
# Processing Record 39 in Set 5 | maxixe
# Processing Record 40 in Set 5 | biak
# Processing Record 41 in Set 5 | juruti
# Processing Record 42 in Set 5 | tahe
# Processing Record 43 in Set 5 | winnemucca
# Processing Record 44 in Set 5 | toliary
# City not found, skipping
# Processing Record 44 in Set 5 | dakar
# Processing Record 45 in Set 5 | turka
# Processing Record 46 in Set 5 | medea
# Processing Record 47 in Set 5 | pemangkat
# City not found, skipping
# Processing Record 47 in Set 5 | richards bay
# Processing Record 48 in Set 5 | adrar
# Processing Record 49 in Set 5 | cabra
# Processing Record 50 in Set 5 | kamaishi
# Processing Record 1 in Set 6 | byron bay
# Processing Record 2 in Set 6 | todos santos
# Processing Record 3 in Set 6 | diapaga
# Processing Record 4 in Set 6 | suarez
# Processing Record 5 in Set 6 | constantine
# Processing Record 6 in Set 6 | cayenne
# Processing Record 7 in Set 6 | cassilandia
# Processing Record 8 in Set 6 | vredendal
# Processing Record 9 in Set 6 | masuguru
# Processing Record 10 in Set 6 | fortuna
# Processing Record 11 in Set 6 | marcona
# City not found, skipping
# Processing Record 11 in Set 6 | krasnaya polyana
# Processing Record 12 in Set 6 | samusu
# City not found, skipping
# Processing Record 12 in Set 6 | hobe sound
# Processing Record 13 in Set 6 | banda aceh
# Processing Record 14 in Set 6 | yanan
# City not found, skipping
# Processing Record 14 in Set 6 | sept-iles
# Processing Record 15 in Set 6 | rio grande
# Processing Record 16 in Set 6 | vero beach
# Processing Record 17 in Set 6 | sobolevo
# Processing Record 18 in Set 6 | zatoka
# Processing Record 19 in Set 6 | lazaro cardenas
# Processing Record 20 in Set 6 | marfino
# Processing Record 21 in Set 6 | wilkie
# Processing Record 22 in Set 6 | port blair
# Processing Record 23 in Set 6 | half moon bay
# Processing Record 24 in Set 6 | palana
# Processing Record 25 in Set 6 | rokytne
# Processing Record 26 in Set 6 | garden city
# Processing Record 27 in Set 6 | paamiut
# Processing Record 28 in Set 6 | novokayakent
# Processing Record 29 in Set 6 | waipawa
# Processing Record 30 in Set 6 | russkaya polyana
# Processing Record 31 in Set 6 | nizhneyansk
# City not found, skipping
# Processing Record 31 in Set 6 | kirakira
# Processing Record 32 in Set 6 | gamba
# Processing Record 33 in Set 6 | iqaluit
# Processing Record 34 in Set 6 | thohoyandou
# Processing Record 35 in Set 6 | swellendam
# Processing Record 36 in Set 6 | astana
# Processing Record 37 in Set 6 | maceio
# Processing Record 38 in Set 6 | bhind
# Processing Record 39 in Set 6 | romny
# Processing Record 40 in Set 6 | touros
# Processing Record 41 in Set 6 | mandalgovi
# Processing Record 42 in Set 6 | eirunepe
# Processing Record 43 in Set 6 | kamloops
# Processing Record 44 in Set 6 | aklavik
# Processing Record 45 in Set 6 | maniitsoq
# Processing Record 46 in Set 6 | paragould
# Processing Record 47 in Set 6 | pangnirtung
# Processing Record 48 in Set 6 | umm lajj
# Processing Record 49 in Set 6 | tuktoyaktuk
# Processing Record 50 in Set 6 | inagi
# Processing Record 1 in Set 7 | arkhangelos
# City not found, skipping
# Processing Record 1 in Set 7 | grand river south east
# City not found, skipping
# Processing Record 1 in Set 7 | mizque
# Processing Record 2 in Set 7 | yirol
# City not found, skipping
# Processing Record 2 in Set 7 | taltal
# Processing Record 3 in Set 7 | djibo
# Processing Record 4 in Set 7 | pijijiapan
# Processing Record 5 in Set 7 | bozdar
# Processing Record 6 in Set 7 | lakes entrance
# Processing Record 7 in Set 7 | harper
# Processing Record 8 in Set 7 | polyarnyy
# Processing Record 9 in Set 7 | marzuq
# Processing Record 10 in Set 7 | coffs harbour
# Processing Record 11 in Set 7 | madang
# Processing Record 12 in Set 7 | nizwa
# Processing Record 13 in Set 7 | darnah
# Processing Record 14 in Set 7 | lingao
# Processing Record 15 in Set 7 | meadow lake
# Processing Record 16 in Set 7 | oranjemund
# Processing Record 17 in Set 7 | hamilton
# Processing Record 18 in Set 7 | kaeo
# Processing Record 19 in Set 7 | barcelona
# Processing Record 20 in Set 7 | saint-avold
# Processing Record 21 in Set 7 | carbonia
# Processing Record 22 in Set 7 | dhidhdhoo
# Processing Record 23 in Set 7 | serro
# Processing Record 24 in Set 7 | chuy
# Processing Record 25 in Set 7 | pelotas
# Processing Record 26 in Set 7 | concordia
# Processing Record 27 in Set 7 | vanimo
# Processing Record 28 in Set 7 | nemuro
# Processing Record 29 in Set 7 | zanjan
# Processing Record 30 in Set 7 | tezu
# Processing Record 31 in Set 7 | madarjac
# City not found, skipping
# Processing Record 31 in Set 7 | wanlaweyn
# Processing Record 32 in Set 7 | vuktyl
# Processing Record 33 in Set 7 | gangotri
# City not found, skipping
# Processing Record 33 in Set 7 | milkovo
# Processing Record 34 in Set 7 | bonthe
# Processing Record 35 in Set 7 | at-bashi
# Processing Record 36 in Set 7 | teya
# Processing Record 37 in Set 7 | kavieng
# Processing Record 38 in Set 7 | geraldton
# Processing Record 39 in Set 7 | mae sot
# Processing Record 40 in Set 7 | torbay
# Processing Record 41 in Set 7 | muros
# Processing Record 42 in Set 7 | kerteh
# City not found, skipping
# Processing Record 42 in Set 7 | sladkovo
# Processing Record 43 in Set 7 | riyadh
# Processing Record 44 in Set 7 | faya
# Processing Record 45 in Set 7 | college
# Processing Record 46 in Set 7 | coquimbo
# Processing Record 47 in Set 7 | pullman
# Processing Record 48 in Set 7 | brae
# Processing Record 49 in Set 7 | virden
# Processing Record 50 in Set 7 | tambura
# City not found, skipping
# Processing Record 50 in Set 7 | redding
# Processing Record 1 in Set 8 | ler
# Processing Record 2 in Set 8 | gat
# Processing Record 3 in Set 8 | scottsbluff
# Processing Record 4 in Set 8 | zhigansk
# Processing Record 5 in Set 8 | yerbogachen
# Processing Record 6 in Set 8 | igrim
# Processing Record 7 in Set 8 | qingdao
# Processing Record 8 in Set 8 | cidreira
# Processing Record 9 in Set 8 | comodoro rivadavia
# Processing Record 10 in Set 8 | manta
# Processing Record 11 in Set 8 | melbu
# Processing Record 12 in Set 8 | shellbrook
# Processing Record 13 in Set 8 | live oak
# Processing Record 14 in Set 8 | ust-nera
# Processing Record 15 in Set 8 | klyuchi
# Processing Record 16 in Set 8 | gualeguaychu
# Processing Record 17 in Set 8 | sabha
# Processing Record 18 in Set 8 | acarau
# City not found, skipping
# Processing Record 18 in Set 8 | artsyz
# Processing Record 19 in Set 8 | barcelos
# Processing Record 20 in Set 8 | nieuwpoort
# Processing Record 21 in Set 8 | kupang
# Processing Record 22 in Set 8 | rocha
# Processing Record 23 in Set 8 | palafrugell
# Processing Record 24 in Set 8 | labutta
# City not found, skipping
# Processing Record 24 in Set 8 | lompoc
# Processing Record 25 in Set 8 | alice springs
# Processing Record 26 in Set 8 | namibe
# Processing Record 27 in Set 8 | astoria
# Processing Record 28 in Set 8 | dikson
# Processing Record 29 in Set 8 | lukovetskiy
# Processing Record 30 in Set 8 | ormara
# Processing Record 31 in Set 8 | mnogovershinnyy
# Processing Record 32 in Set 8 | halifax
# Processing Record 33 in Set 8 | balsas
# Processing Record 34 in Set 8 | liepaja
# Processing Record 35 in Set 8 | mariental
# Processing Record 36 in Set 8 | sint michiel
# City not found, skipping
# Processing Record 36 in Set 8 | xai-xai
# Processing Record 37 in Set 8 | nicoya
# Processing Record 38 in Set 8 | amboise
# Processing Record 39 in Set 8 | port hawkesbury
# Processing Record 40 in Set 8 | korhogo
# Processing Record 41 in Set 8 | solnechnyy
# Processing Record 42 in Set 8 | haines junction
# Processing Record 43 in Set 8 | micheweni
# Processing Record 44 in Set 8 | alofi
# Processing Record 45 in Set 8 | ambon
# Processing Record 46 in Set 8 | bambanglipuro
# Processing Record 47 in Set 8 | balclutha
# Processing Record 48 in Set 8 | nueva loja
# Processing Record 49 in Set 8 | taloda
# Processing Record 50 in Set 8 | san quintin
# Processing Record 1 in Set 9 | te anau
# Processing Record 2 in Set 9 | acari
# Processing Record 3 in Set 9 | jardim
# Processing Record 4 in Set 9 | beringovskiy
# Processing Record 5 in Set 9 | amahai
# Processing Record 6 in Set 9 | canmore
# Processing Record 7 in Set 9 | iguape
# Processing Record 8 in Set 9 | manokwari
# Processing Record 9 in Set 9 | george town
# Processing Record 10 in Set 9 | araouane
# Processing Record 11 in Set 9 | demidov
# Processing Record 12 in Set 9 | srednekolymsk
# Processing Record 13 in Set 9 | killam
# Processing Record 14 in Set 9 | orleans
# Processing Record 15 in Set 9 | lom sak
# Processing Record 16 in Set 9 | sarkand
# Processing Record 17 in Set 9 | asau
# City not found, skipping
# Processing Record 17 in Set 9 | acapulco
# Processing Record 18 in Set 9 | faanui
# Processing Record 19 in Set 9 | gejiu
# Processing Record 20 in Set 9 | henties bay
# Processing Record 21 in Set 9 | nalut
# Processing Record 22 in Set 9 | salamiyah
# Processing Record 23 in Set 9 | dzhusaly
# City not found, skipping
# Processing Record 23 in Set 9 | port hedland
# Processing Record 24 in Set 9 | boleslawiec
# Processing Record 25 in Set 9 | ostrovnoy
# Processing Record 26 in Set 9 | mahibadhoo
# Processing Record 27 in Set 9 | banjar
# Processing Record 28 in Set 9 | san ramon
# Processing Record 29 in Set 9 | jinchang
# Processing Record 30 in Set 9 | xifeng
# Processing Record 31 in Set 9 | pitimbu
# Processing Record 32 in Set 9 | tessalit
# Processing Record 33 in Set 9 | narsaq
# Processing Record 34 in Set 9 | sao felix do xingu
# Processing Record 35 in Set 9 | amderma
# City not found, skipping
# Processing Record 35 in Set 9 | the pas
# Processing Record 36 in Set 9 | kegayli
# City not found, skipping
# Processing Record 36 in Set 9 | suao
# City not found, skipping
# Processing Record 36 in Set 9 | agirish
# Processing Record 37 in Set 9 | fomboni
# Processing Record 38 in Set 9 | yialos
# City not found, skipping
# Processing Record 38 in Set 9 | tila
# Processing Record 39 in Set 9 | devils lake
# Processing Record 40 in Set 9 | cockburn town
# Processing Record 41 in Set 9 | port antonio
# Processing Record 42 in Set 9 | la ronge
# Processing Record 43 in Set 9 | huarmey
# Processing Record 44 in Set 9 | laguna
# Processing Record 45 in Set 9 | clonakilty
# Processing Record 46 in Set 9 | bathsheba
# Processing Record 47 in Set 9 | lata
# Processing Record 48 in Set 9 | abha
# Processing Record 49 in Set 9 | altamont
# Processing Record 50 in Set 9 | porto novo
# Processing Record 1 in Set 10 | kaili
# Processing Record 2 in Set 10 | thinadhoo
# Processing Record 3 in Set 10 | chulym
# Processing Record 4 in Set 10 | sao joao da barra
# Processing Record 5 in Set 10 | vilcun
# Processing Record 6 in Set 10 | nanortalik
# Processing Record 7 in Set 10 | rawannawi
# City not found, skipping
# Processing Record 7 in Set 10 | caxias
# Processing Record 8 in Set 10 | dingle
# Processing Record 9 in Set 10 | santa rosa
# Processing Record 10 in Set 10 | nouadhibou
# Processing Record 11 in Set 10 | hami
# Processing Record 12 in Set 10 | rawah
# City not found, skipping
# Processing Record 12 in Set 10 | viedma
# Processing Record 13 in Set 10 | cap malheureux
# Processing Record 14 in Set 10 | hobyo
# Processing Record 15 in Set 10 | sangar
# Processing Record 16 in Set 10 | santa cruz
# Processing Record 17 in Set 10 | cumaribo
# City not found, skipping
# Processing Record 17 in Set 10 | leningradskiy
# Processing Record 18 in Set 10 | dvinskoy
# Processing Record 19 in Set 10 | swan river
# Processing Record 20 in Set 10 | hay river
# Processing Record 21 in Set 10 | kutum
# Processing Record 22 in Set 10 | kibaya
# Processing Record 23 in Set 10 | clyde river
# Processing Record 24 in Set 10 | churapcha
# Processing Record 25 in Set 10 | takoradi
# Processing Record 26 in Set 10 | caraguatay
# Processing Record 27 in Set 10 | leh
# Processing Record 28 in Set 10 | kajaani
# Processing Record 29 in Set 10 | kurumkan
# Processing Record 30 in Set 10 | lalmanir hat
# City not found, skipping
# Processing Record 30 in Set 10 | lotofaga
# Processing Record 31 in Set 10 | demba
# Processing Record 32 in Set 10 | portland
# Processing Record 33 in Set 10 | margherita
# Processing Record 34 in Set 10 | sangmelima
# Processing Record 35 in Set 10 | vila velha
# Processing Record 36 in Set 10 | nova russas
# Processing Record 37 in Set 10 | codrington
# Processing Record 38 in Set 10 | mount gambier
# Processing Record 39 in Set 10 | serenje
# Processing Record 40 in Set 10 | santa isabel
# Processing Record 41 in Set 10 | sukhumi
# City not found, skipping
# Processing Record 41 in Set 10 | cuiluan
# Processing Record 42 in Set 10 | povenets
# Processing Record 43 in Set 10 | catole do rocha
# Processing Record 44 in Set 10 | nouakchott
# Processing Record 45 in Set 10 | rungata
# City not found, skipping
# Processing Record 45 in Set 10 | portage
# Processing Record 46 in Set 10 | yeppoon
# Processing Record 47 in Set 10 | smithers
# Processing Record 48 in Set 10 | santiago de chuco
# Processing Record 49 in Set 10 | rancharia
# Processing Record 50 in Set 10 | la rioja
# Processing Record 1 in Set 11 | dingzhou
# Processing Record 2 in Set 11 | buariki
# City not found, skipping
# Processing Record 2 in Set 11 | salinopolis
# Processing Record 3 in Set 11 | urgut
# Processing Record 4 in Set 11 | tabiauea
# City not found, skipping
# Processing Record 4 in Set 11 | petropavlovsk-kamchatskiy
# Processing Record 5 in Set 11 | halalo
# City not found, skipping
# Processing Record 5 in Set 11 | langenburg
# Processing Record 6 in Set 11 | tarudant
# City not found, skipping
# Processing Record 6 in Set 11 | mayo
# Processing Record 7 in Set 11 | dunedin
# Processing Record 8 in Set 11 | kloulklubed
# Processing Record 9 in Set 11 | staraya russa
# Processing Record 10 in Set 11 | kerki
# City not found, skipping
# Processing Record 10 in Set 11 | hat yai
# Processing Record 11 in Set 11 | stei
# City not found, skipping
# Processing Record 11 in Set 11 | borovichi
# Processing Record 12 in Set 11 | inverell
# Processing Record 13 in Set 11 | namatanai
# Processing Record 14 in Set 11 | jiayuguan
# Processing Record 15 in Set 11 | songea
# Processing Record 16 in Set 11 | vostok
# Processing Record 17 in Set 11 | saquarema
# Processing Record 18 in Set 11 | vanavara
# Processing Record 19 in Set 11 | ballina
# Processing Record 20 in Set 11 | oriximina
# Processing Record 21 in Set 11 | mastic beach
# Processing Record 22 in Set 11 | hudson bay
# Processing Record 23 in Set 11 | chapais
# Processing Record 24 in Set 11 | abu kamal
# Processing Record 25 in Set 11 | taksimo
# Processing Record 26 in Set 11 | wad madani
# City not found, skipping
# Processing Record 26 in Set 11 | zhicheng
# Processing Record 27 in Set 11 | porciuncula
# Processing Record 28 in Set 11 | ngama
# City not found, skipping
# Processing Record 28 in Set 11 | hongjiang
# Processing Record 29 in Set 11 | opuwo
# Processing Record 30 in Set 11 | salym
# Processing Record 31 in Set 11 | casino
# Processing Record 32 in Set 11 | kangaatsiaq
# Processing Record 33 in Set 11 | nizhniy kuranakh
# Processing Record 34 in Set 11 | bandundu
# Processing Record 35 in Set 11 | juneau
# Processing Record 36 in Set 11 | iiyama
# Processing Record 37 in Set 11 | goderich
# Processing Record 38 in Set 11 | sechura
# Processing Record 39 in Set 11 | mezen
# Processing Record 40 in Set 11 | we
# City not found, skipping
# Processing Record 40 in Set 11 | sandanski
# Processing Record 41 in Set 11 | kenai
# Processing Record 42 in Set 11 | kaka
# Processing Record 43 in Set 11 | nelson bay
# Processing Record 44 in Set 11 | jieshi
# Processing Record 45 in Set 11 | the valley
# Processing Record 46 in Set 11 | rodrigues alves
# Processing Record 47 in Set 11 | krasnoye
# Processing Record 48 in Set 11 | pisco
# Processing Record 49 in Set 11 | point pleasant
# Processing Record 50 in Set 11 | fort saint james
# Processing Record 1 in Set 12 | iralaya
# Processing Record 2 in Set 12 | shimoda
# Processing Record 3 in Set 12 | iwaki
# Processing Record 4 in Set 12 | ewa beach
# Processing Record 5 in Set 12 | zlobin
# Processing Record 6 in Set 12 | san luis rio colorado
# -----------------
# Data Gathering Complete

# %%
weather_lists = {'City Name':name, 'Country':country, 'Date Time':date, 'Latitude':lat, 'Longitude':long, 'Temperature':temp, 'Humidity':humid, 'Cloudiness':cloud, 'Wind Speed':wind}
weather_df = pd.DataFrame(weather_lists)
conv_date = datetime.utcfromtimestamp(date[0]).strftime('%m/%d/%Y')
weather_df.head()
# Out:
# '09/21/2019'

# %%
# Write to csv
weather_df.to_csv('Weather_Data.csv', header=True, index=False)

# %%
# Temperature (F) vs. Latitude
plt.scatter(lat, temp, marker='o', edgecolors='black')
plt.grid(axis='both')
plt.suptitle(f'City Latitude vs. Max Temperature (F) ({conv_date})')
plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
plt.savefig("Temp_vs_Lat.png")
plt.show()

# %%
# Humidity (%) vs. Latitude
plt.scatter(lat, humid, marker='o', edgecolors='black')
plt.grid(axis='both')
plt.suptitle(f'City Latitude vs. Humidity (%) ({conv_date})')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.ylim(bottom=0, top=105)
plt.savefig("Humid_vs_Lat.png")
plt.show()

# %%
# Cloudiness (%) vs. Latitude
plt.scatter(lat, cloud, marker='o', edgecolors='black')
plt.grid(axis='both')
plt.suptitle(f'City Latitude vs. Cloudiness (%) ({conv_date})')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylim(bottom=0, top=105)
plt.savefig("Cloud_vs_Lat.png")
plt.show()

# %%
# Wind Speed (mph) vs. Latitude
plt.scatter(lat, wind, marker='o', edgecolors='black')
plt.grid(axis='both')
plt.suptitle(f'City Latitude vs. Wind Speed (mph) ({conv_date})')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.savefig("Wind_vs_Lat.png")
plt.show()
